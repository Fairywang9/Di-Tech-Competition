# %%
import pandas as pd
import numpy as np
submission = pd.read_csv('submission1.csv', sep = ',', dtype = str, header = None)

# %%
pred_clf1 = np.loadtxt('pred_clf1.txt', delimiter=' ')

# %%
submission[2] = pred_clf1
submission = submission.drop(submission[submission[1] == '2016-01-25-46'].index)
submission = submission.drop(submission[submission[1] == '2016-01-29-46'].index)
submission.to_csv('submission.csv', index = False, header = False)

# %%
submission
# Out:
#        0               1    2
# 0      1   2016-01-23-46  5.0
# 1      2   2016-01-23-46  0.0
# 2      3   2016-01-23-46  0.0
# 3      4   2016-01-23-46  5.0
# 4      5   2016-01-23-46  0.0
# 5      6   2016-01-23-46  5.0
# 6      7   2016-01-23-46  5.0
# 7      8   2016-01-23-46  5.0
# 8      9   2016-01-23-46  1.0
# 9     10   2016-01-23-46  0.0
# 10    11   2016-01-23-46  5.0
# 11    12   2016-01-23-46  5.0
# 12    13   2016-01-23-46  0.0
# 13    14   2016-01-23-46  5.0
# 14    15   2016-01-23-46  0.0
# 15    16   2016-01-23-46  0.0
# 16    17   2016-01-23-46  0.0
# 17    18   2016-01-23-46  0.0
# 18    19   2016-01-23-46  5.0
# 19    20   2016-01-23-46  5.0
# 20    21   2016-01-23-46  5.0
# 21    22   2016-01-23-46  5.0
# 22    23   2016-01-23-46  5.0
# 23    24   2016-01-23-46  5.0
# 24    25   2016-01-23-46  5.0
# 25    26   2016-01-23-46  5.0
# 26    27   2016-01-23-46  5.0
# 27    28   2016-01-23-46  5.0
# 28    29   2016-01-23-46  5.0
# 29    30   2016-01-23-46  0.0
# ...

# %%
pred_clf1.shape
# Out:
# (2970,)

# %%
submission.shape
# Out:
# (2838, 3)

# %%
test = pd.read_csv('test.csv', sep = ',', dtype = str, header = None) 
test.shape
# Out:
# (2838, 3)
